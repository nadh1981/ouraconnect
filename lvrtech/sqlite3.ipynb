# %%
import sqlite3
import requests
from datetime import datetime, timedelta

# %%
con = sqlite3.connect("../db/TwinFit.db")

# %%
def create_user(id, email, token):
    con.execute('''CREATE TABLE IF NOT EXISTS users (id integer PRIMARY KEY, token text, email text)''')
    con.execute('''INSERT INTO USERS (id, token, email) VALUES (id, token, email)''')

# %%
baseurl = "https://api.ouraring.com/v1"
accesstoken = "KRUITYEDW4GVAZ6NPWOIRIITZL2YBIW6"

# %%
userinfo = requests.get(f"{baseurl}/userinfo?access_token={accesstoken}")

# %%
info = userinfo.json()

# %%
info

# %%
info["age"]

# %%
yesterday = datetime.now() - timedelta(7)

# %%
datetime.strftime(yesterday, '%Y-%m-%d')

# %%
def make_base_url(accesstoken, entity, start_date, end_date):
    if start_date == None:
        start_date = datetime.now() - timedelta(7)
        start_date = datetime.strftime(start_date, '%Y-%m-%d')
    url = ''
    
    if end_date == None:
        url = f"{baseurl}/{entity}?access_token={accesstoken}&start={start_date}"
    else:
        url = f"{baseurl}/{entity}?access_token={accesstoken}&end={end_date}"

    return url

def get_readiness_summary(accesstoken, start_date=None, end_date=None):
    print(make_base_url(accesstoken, "readiness", start_date, end_date))
    readiness_summary = requests.get(make_base_url(accesstoken, "readiness", start_date, end_date)).json()
    return readiness_summary

def get_activity_summary(accesstoken, start_date=None, end_date=None):
    print(make_base_url(accesstoken, "activity", start_date, end_date))
    activity_summary = requests.get(make_base_url(accesstoken, "activity", start_date, end_date)).json()
    return activity_summary

def get_sleep_summary(accesstoken, start_date=None, end_date=None):
    print(make_base_url(accesstoken, "activity", start_date, end_date))
    sleep_summary = requests.get(make_base_url(accesstoken, "sleep", start_date, end_date)).json()
    return sleep_summary

# %%
get_readiness_summary(accesstoken)

# %%
activity = get_activity_summary(accesstoken)

# %%
keys = activity['activity'][0].keys()

# %%
for key in keys:
    print(key)

# %%
print(activity['activity'][0].values())

# %%
activity['activity'][0].keys()
# Out:
# dict_keys(['summary_date', 'timezone', 'day_start', 'day_end', 'cal_active', 'cal_total', 'class_5min', 'steps', 'daily_movement', 'non_wear', 'rest', 'inactive', 'low', 'medium', 'high', 'inactivity_alerts', 'average_met', 'met_1min', 'met_min_inactive', 'met_min_low', 'met_min_medium', 'met_min_high', 'target_calories', 'target_km', 'target_miles', 'to_target_km', 'to_target_miles', 'score', 'score_meet_daily_targets', 'score_move_every_hour', 'score_recovery_time', 'score_stay_active', 'score_training_frequency', 'score_training_volume', 'rest_mode_state', 'total'])

# %%
columns = ', '.join(activity['activity'][0].keys())
placeholders = ', '.join('?' * len(activity['activity'][0]))
sql = 'INSERT INTO Media ({}) VALUES ({})'.format(columns, placeholders)
values = [int(x) if isinstance(x, bool) else x for x in activity['activity'][0].values()]

# %%
for activity_item in activity['activity']:   
        activity_item["met_1min"] = "|".join([str(x) for x in activity_item["met_1min"]])
        columns = "token, " + ', '.join(activity_item.keys())
        placeholders = "?, " + ', '.join('?' * len(activity_item))
        print(placeholders)
        sql = 'INSERT OR REPLACE INTO activity ({}) VALUES ({})'.format(columns, placeholders)                
        values = [x if isinstance(x, bool) else x for x in activity_item.values()]              
        print(values)
#         print("error values is")
#         print(values[18])
#         print(sql, values)
# Out:
# ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?
# ...
